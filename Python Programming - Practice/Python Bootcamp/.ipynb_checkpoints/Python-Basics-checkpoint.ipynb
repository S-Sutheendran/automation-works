# %% [markdown]
# # Python Numbers

# %%
2 + 3
# Out:
# 5

# %%
2 - 3
# Out:
# -1

# %%
2 * 2
# Out:
# 4

# %%
2/3
# Out:
# 0.6666666666666666

# %%
7/4
# Out:
# 1.75

# %%
7%5
# Out:
# 2

# %%
2 ** 3
# Out:
# 8

# %%
2+10 * 10+3
# Out:
# 105

# %%
(2+10) * (10+3)
# Out:
# 156

# %% [markdown]
# # Variables

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
a = a + 10

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
a = "John"

# %%
type(a)
# Out:
# str

# %%
a = 10.5

# %%
type(a)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0

# %% [markdown]
# # Strings

# %%
"hello"
# Out:
# 'hello'

# %%
'hello'
# Out:
# 'hello'

# %%
'this is also string'
# Out:
# 'this is also string'

# %%
'I'm going on a run' # This will throw an error
# Out:
#   Cell In[31], line 1
#     'I'm going on a run' # This will throw an error
#                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I'm going to run"
# Out:
# "I'm going to run"

# %%
print("Hello")
# Out:
# Hello

# %%
"hello one"
"hello two"
# Out:
# 'hello two'

# %%
print("hello one")
print("hello two")
# Out:
# hello one
# hello two

# %%
# escape sequence
print("Hello \n World")
# Out:
# Hello
#  World

# %%
print("Hellow \t World")
# Out:
# Hellow 	 World

# %%
len("Hello")
# Out:
# 5

# %%
len('I am')
# Out:
# 4

# %% [markdown]
# # Indexing & Slicing

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring[0:4:2]
# Out:
# 'Hl'

# %%
mystring[0:4:1]
# Out:
# 'Hell'

# %%
mystring[4:]
# Out:
# 'o World'

# %%
mystring[0:-4:1]
# Out:
# 'Hello W'

# %%
mystring[::]
# Out:
# 'Hello World'

# %%
mystring[:]
# Out:
# 'Hello World'

# %% [markdown]
# # String Properties & Methods

# %%
name = "Sam"

# %%
name[0] = 'P'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 name[0] = 'P'
#
# TypeError: 'str' object does not support item assignment

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %%
name = "z"

# %%
name * 10
# Out:
# 'zzzzzzzzzz'

# %%
name = "Hello World"

# %%
name.split('l')
# Out:
# ['He', '', 'o Wor', 'd']

# %%
name.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# # String Formatting & Printing

# %%
print("This is a String {}" .format("Inserted"))
# Out:
# This is a String Inserted

# %%
print("The {2} {1} {0}" .format('Fox', 'brown', 'quick'))
# Out:
# The quick brown Fox

# %%
print("The {0} {0} {0}" .format('Fox', 'brown', 'quick'))
# Out:
# The Fox Fox Fox

# %%
print("The {} {} {}" .format('Fox', 'brown', 'quick'))
# Out:
# The Fox brown quick

# %%
print("The {q} {b} {f}" .format(f='Fox', b='brown', q='quick'))
# Out:
# The quick brown Fox

# %%
result = 0.5777777

# %%
print("The result is {}".format(result))
# Out:
# The result is 0.5777777

# %%
print("The result is {r:2.5f}".format(r=result))
# Out:
# The result is 0.57778

# %%
name = "Susi"

# %%
print(f"My name is {name}")
# Out:
# My name is Susi

# %%
name = "Susi"
age = 50

# %%
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Susi and I am 50 years old
