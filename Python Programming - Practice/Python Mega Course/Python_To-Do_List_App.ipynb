# %% [markdown]
# # This is the Starting of my Python Journey
# - This is a Mega Course
# - Seperated with Days and apps which will be built based on course
# - This will be an E2E Python course
#
# All the Best

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # To-Do List App:
# - Basic Printing Text
# - Getting user input

# %%
user_input = input("Enter To-Do: ")
print("To-Do: ",user_input)
# Out:
# Enter To-Do:  Throw the trash
# To-Do:  Throw the trash

# %%
todo_1 = input("Enter To-Do: ")
todo_2 = input("Enter To-Do: ")
todo_3 = input("Enter To-Do: ")

todo_list = [todo_1, todo_2, todo_3]
print("To-Do List: ",todo_list)
# Out:
# Enter To-Do:  Meet John
# Enter To-Do:  Connect with Smith
# Enter To-Do:  Throw the Trash
# To-Do List:  ['Meet John', 'Connect with Smith', 'Throw the Trash']

# %%
type(todo_1)
# Out:
# str

# %%
type(todo_list)
# Out:
# list
